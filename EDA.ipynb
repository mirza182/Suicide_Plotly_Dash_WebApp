# %%
# Cell 1: Import Libraries and Load Data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('master.csv')

# %%
# Displaying the first few rows of the dataset
print("\nFirst few rows of the dataset:\n", data.head())
# Out:
# First few rows of the dataset:
#     country  year     sex          age  suicides_no  population  suicides/100k  \
# 0  Albania  1987    male  15-24 years           21      312900           6.71
# 1  Albania  1987    male  35-54 years           16      308000           5.19
# 2  Albania  1987  female  15-24 years           14      289700           4.83
# 3  Albania  1987    male    75+ years            1       21800           4.59
# 4  Albania  1987    male  25-34 years            9      274300           3.28
#
#   country-year   gdp_for_year_Dollars   gdp_per_capita_Dollars generation
# 0  Albania1987            2.156625e+09                     796      Gen X
# 1  Albania1987            2.156625e+09                     796     Silent
# 2  Albania1987            2.156625e+09                     796      Gen X
# 3  Albania1987            2.156625e+09                     796    G.I Gen
# 4  Albania1987            2.156625e+09                     796    Boomers

# %%
# Checking the data types of each column
print("\nData types of each column:\n", data.dtypes)
# Out:
# Data types of each column:
#  country                    object
# year                        int64
# sex                        object
# age                        object
# suicides_no                 int64
# population                  int64
# suicides/100k             float64
# country-year               object
#  gdp_for_year_Dollars     float64
# gdp_per_capita_Dollars      int64
# generation                 object
# dtype: object

# %%
# Cell 2: Basic Data Exploration
print("Shape:", data.shape)
# Out:
# Shape: (27820, 11)

# %%
print("Columns:", data.columns)
# Out:
# Columns: Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k', 'country-year', ' gdp_for_year_Dollars ',
#        'gdp_per_capita_Dollars', 'generation'],
#       dtype='object')

# %%
print("Summary Statistics:", data.describe())
# Out:
# Summary Statistics:                year   suicides_no    population  suicides/100k  \
# count  27820.000000  27820.000000  2.782000e+04   27820.000000
# mean    2001.258375    242.574407  1.844794e+06      12.816097
# std        8.469055    902.047917  3.911779e+06      18.961511
# min     1985.000000      0.000000  2.780000e+02       0.000000
# 25%     1995.000000      3.000000  9.749850e+04       0.920000
# 50%     2002.000000     25.000000  4.301500e+05       5.990000
# 75%     2008.000000    131.000000  1.486143e+06      16.620000
# max     2016.000000  22338.000000  4.380521e+07     224.970000
#
#         gdp_for_year_Dollars   gdp_per_capita_Dollars
# count            2.782000e+04            27820.000000
# mean             4.455979e+11            16866.464414
# std              1.453907e+12            18887.576472
# min              4.691962e+07              251.000000
# 25%              8.985353e+09             3447.000000
# ...

# %%
# Cell 3: Check for Missing Values
print("Missing Values:", data.isnull().sum())
# Out:
# Missing Values: country                   0
# year                      0
# sex                       0
# age                       0
# suicides_no               0
# population                0
# suicides/100k             0
# country-year              0
#  gdp_for_year_Dollars     0
# gdp_per_capita_Dollars    0
# generation                0
# dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='country', data=data)
plt.xticks(rotation=90)
plt.title('Distribution of Suicides across Countries')
plt.show()

# %%
# Line plot: Suicide rates over time
plt.figure(figsize=(12, 6))
sns.lineplot(x='year', y='suicides/100k', data=data)
plt.title('Suicide Rates over Time')
plt.show()

# %%
# Scatter plot: Relationship between suicide rates and GDP
plt.figure(figsize=(12, 6))
sns.scatterplot(x='gdp_per_capita_Dollars', y='suicides/100k', data=data)
plt.title('Relationship between Suicide Rates and GDP per Capita')
plt.show()

# %%
# Cell 6: Visualization - Suicides by Age Group
plt.figure(figsize=(10, 6))
sns.barplot(x='age', y='suicides_no', data=df)
plt.title("Suicides by Age Group")
plt.show()

# %%
correlation = data[['suicides_no', 'population', 'gdp_per_capita_Dollars']].corr()
print("\nCorrelation between variables:\n", correlation)
# Out:
# Correlation between variables:
#                          suicides_no  population  gdp_per_capita_Dollars
# suicides_no                1.000000    0.616162                 0.06133
# population                 0.616162    1.000000                 0.08151
# gdp_per_capita_Dollars     0.061330    0.081510                 1.00000
